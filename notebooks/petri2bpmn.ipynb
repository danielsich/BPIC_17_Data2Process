# %% [markdown]
# # Load and transform the models to BPMN
# - for easier understanding and decision minining

# %% [markdown]
# - import relevant libraries and petri nets

# %%
import pm4py
import os

# %% [markdown]
# - load in the intresting petri nets

# %%
heuristic_1_net, heuristic_1_initial_marking, heuristic_1_final_marking = pm4py.read_pnml("../petrinets/heuristic_variants/petri_model_1.pnml")
heuristic_1_bpmn_graph = pm4py.convert_to_bpmn(heuristic_1_net, heuristic_1_initial_marking, heuristic_1_final_marking)
pm4py.view_bpmn(heuristic_1_bpmn_graph)

# %%
alpha_1_net, alpha_1_initial_marking, alpha_1_final_marking = pm4py.read_pnml("../petrinets/alpha_variants/petri_model_1.pnml")
alpha_1_bpmn_graph = pm4py.convert_to_bpmn(alpha_1_net, alpha_1_initial_marking, alpha_1_final_marking)
pm4py.view_bpmn(alpha_1_bpmn_graph)

# %%
inductive_1_net, inductive_1_initial_marking, inductive_1_final_marking = pm4py.read_pnml("../petrinets/inductive_variants/petri_model_1.pnml")
inductive_1_bpmn_graph = pm4py.convert_to_bpmn(inductive_1_net, inductive_1_initial_marking, inductive_1_final_marking)
pm4py.view_bpmn(inductive_1_bpmn_graph)

# %%
genetic_net, genetic_initial_marking, genetic_final_marking = pm4py.read_pnml("../petrinets/genetic/genetic_model.pnml")
genetic_bpmn_graph = pm4py.convert_to_bpmn(genetic_net, genetic_initial_marking, genetic_final_marking)
pm4py.view_bpmn(genetic_bpmn_graph)
